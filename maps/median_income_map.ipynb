# %%
import pandas as pd
% load_ext autoreload
% autoreload 2

# %%
from maps.blockgroups import MedianIncome
from maps.elections import USHouseElectionResult
import folium

# %%
root_dir = '~/Documents/data'
election_result = USHouseElectionResult(root_dir, '2022-05-24', '007')

# %%
mi = MedianIncome(root_dir)
ushouse_7th_median_income = mi.get_median_income(election_result.county_codes)
ushouse_7th_median_income = ushouse_7th_median_income.overlay(election_result.district_map, how='intersection')

# %%
ushouse_7th_median_income = ushouse_7th_median_income.assign(
    median_household_income_scaled=ushouse_7th_median_income.median_household_income / 1000)
ushouse_7th_median_income.head()
# Out:
#           GEOID state county_fips county_code   tract block_group  \
# 0  131210116301    13         121         060  011630           1
# 1  131210114291    13         121         060  011429           1
# 2  131210114331    13         121         060  011433           1
# 3  131210116352    13         121         060  011635           2
# 4  131210116382    13         121         060  011638           2
#
#    median_household_income  median_household_income_moe   id          area  \
# 0                 153487.0                      54120.0  258  8.357765e+08
# 1                 107692.0                      55694.0  258  8.357765e+08
# 2                 225152.0                     118774.0  258  8.357765e+08
# 3                 142011.0                      73215.0  258  8.357765e+08
# 4                  48393.0                       6990.0  258  8.357765e+08
#
#   district  population  ideal_value                      center  \
# 0      007      765137     765136.0  POINT (-84.05953 33.92267)
# 1      007      765137     765136.0  POINT (-84.05953 33.92267)
# 2      007      765137     765136.0  POINT (-84.05953 33.92267)
# 3      007      765137     765136.0  POINT (-84.05953 33.92267)
# 4      007      765137     765136.0  POINT (-84.05953 33.92267)
#
#                                             geometry  \
# 0  POLYGON ((-84.20555 34.06114, -84.20283 34.060...
# 1  POLYGON ((-84.26928 34.02678, -84.26935 34.028...
# 2  POLYGON ((-84.26907 34.01596, -84.26900 34.018...
# 3  POLYGON ((-84.09813 34.05072, -84.09784 34.050...
# 4  POLYGON ((-84.22999 34.04889, -84.22820 34.049...
#
#   median_household_income_bin  median_household_income_scaled
# 0                         200                         153.487
# 1                         125                         107.692
# 2                         300                         225.152
# 3                         150                         142.011
# 4                          50                          48.393

# %%
election_result_map = election_result.district_map
center = election_result_map.center.iloc[0]
m = folium.Map(location=[center.y, center.x])
bbox = election_result_map.bounds.iloc[0]
m.fit_bounds([[bbox.miny, bbox.minx], [bbox.maxy, bbox.maxx]])

folium.Choropleth(
    bins=7,
    geo_data=ushouse_7th_median_income[['GEOID', 'geometry']],
    name="choropleth",
    data=ushouse_7th_median_income[['GEOID', 'median_household_income_scaled']],
    columns=["GEOID", "median_household_income_scaled"],
    key_on="feature.properties.GEOID",
    fill_color="YlGn",
    fill_opacity=0.7,
    line_opacity=0.0,
    line_weight=0,
    legend_name="Median Income ($1000s)",
    highlight=True
).add_to(m)

m

af = election_result.results[['county_code', 'precinct_name', 'party', 'votes']].\
    groupby(['county_code', 'precinct_name', 'party']).\
    sum().reset_index()

af = af.pivot(index=['county_code', 'precinct_name'], columns='party', values='votes')
af.columns.name = None
af = af.reset_index()
af = af.assign(affinity=(af.REP / (af.REP + af.DEM)).apply(lambda x: (max(.4, min(.6, x)) - 0.4) / 0.2),
               pop_scale=(af.REP + af.DEM) / (af.REP + af.DEM).max())

vtd_maps = election_result.vtd_maps

af_marker = af.merge(vtd_maps[['county_code', 'precinct_name', 'center']], on=['county_code', 'precinct_name'],
                     how='inner')
print(af_marker.head())

import plotly.express as px
from plotly.colors import n_colors, find_intermediate_color

for i in af_marker.index:
    center = af_marker.loc[i].center
    x = center.x
    y = center.y
    r = af_marker.loc[i].pop_scale * 20
    c = '#' + ''.join(['%02x' % int(x) for x in find_intermediate_color((0, 0, 255), (255, 0, 0), af_marker.loc[i].affinity)])
    pn = af_marker.loc[i].precinct_name.replace(' ', '&nbsp;')
    rep = af_marker.loc[i].REP
    dem = af_marker.loc[i].DEM
    line2 = f'Rep({rep})&nbsp;vs.&nbsp;Dem({dem})'
    text = f'{pn}<br>{line2}'
    folium.CircleMarker(
        location=[y, x],
        radius=r,
        popup=text,
        color=c,
        fill=True,
        fill_color=c,
        fill_opacity = 0.5,
        opacity = 0.5,
        weight = 0.2,

    ).add_to(m)

m
# Out:
#   county_code precinct_name  DEM  REP  affinity  pop_scale  \
# 0         060          JC01  430  468  0.605791   0.514024
# 1         060         JC01A  166  167  0.507508   0.190612
# 2         060          JC02  302  356  0.705167   0.376646
# 3         060         JC03A   51   68  0.857143   0.068117
# 4         060         JC03B  198  166  0.280220   0.208357
#
#                        center
# 0  POINT (-84.15460 34.04544)
# 1  POINT (-84.13240 34.04090)
# 2  POINT (-84.16660 34.05487)
# 3  POINT (-84.19372 34.06655)
# 4  POINT (-84.18597 34.06314)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_086c6a9e2f2a4fe889c190e9c99771fe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_086c6a9e2f2a4fe889c190e9c99771fe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_086c6a9e2f2a4fe889c190e9c99771fe = L.map(
#                 &quot;map_086c6a9e2f2a4fe889c190e9c99771fe&quot;,
#                 {
#                     center: [33.92266807940528, -84.05953456687884],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1e2dff87e6c09851fba3e48f9a1b0916 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_086c6a9e2f2a4fe889c190e9c99771fe);
#
#
#             map_086c6a9e2f2a4fe889c190e9c99771fe.fitBounds(
#                 [[33.75280798999031, -84.29404799999999], [34.09067899016351, -83.799104]],
#                 {}
#             );
#
#
#             var choropleth_4c5e412c9c7e18427916c4bd03bbe122 = L.featureGroup(
#                 {}
#             ).addTo(map_086c6a9e2f2a4fe889c190e9c99771fe);
#
#
#         function geo_json_ae0930dc1faa5a8f4bfdbd748c762195_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;6&quot;: case &quot;7&quot;: case &quot;10&quot;: case &quot;16&quot;: case &quot;18&quot;: case &quot;28&quot;: case &quot;33&quot;: case &quot;35&quot;: case &quot;39&quot;: case &quot;46&quot;: case &quot;53&quot;: case &quot;56&quot;: case &quot;65&quot;: case &quot;69&quot;: case &quot;75&quot;: case &quot;77&quot;: case &quot;90&quot;: case &quot;112&quot;: case &quot;151&quot;: case &quot;178&quot;: case &quot;207&quot;: case &quot;225&quot;: case &quot;254&quot;: case &quot;272&quot;: case &quot;371&quot;: case &quot;386&quot;: case &quot;393&quot;: case &quot;398&quot;: case &quot;473&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#41ab5d&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.0, &quot;weight&quot;: 0};
#                 case &quot;1&quot;: case &quot;5&quot;: case &quot;8&quot;: case &quot;9&quot;: case &quot;15&quot;: case &quot;24&quot;: case &quot;32&quot;: case &quot;36&quot;: case &quot;37&quot;: case &quot;57&quot;: case &quot;72&quot;: case &quot;85&quot;: case &quot;86&quot;: case &quot;88&quot;: case &quot;98&quot;: case &quot;115&quot;: case &quot;117&quot;: case &quot;121&quot;: case &quot;122&quot;: case &quot;132&quot;: case &quot;157&quot;: case &quot;166&quot;: case &quot;170&quot;: case &quot;182&quot;: case &quot;183&quot;: case &quot;191&quot;: case &quot;196&quot;: case &quot;203&quot;: case &quot;217&quot;: case &quot;220&quot;: case &quot;223&quot;: case &quot;234&quot;: case &quot;237&quot;: case &quot;251&quot;: case &quot;252&quot;: case &quot;255&quot;: case &quot;265&quot;: case &quot;267&quot;: case &quot;268&quot;: case &quot;270&quot;: case &quot;271&quot;: case &quot;274&quot;: case &quot;286&quot;: case &quot;287&quot;: case &quot;289&quot;: case &quot;292&quot;: case &quot;304&quot;: case &quot;305&quot;: case &quot;316&quot;: case &quot;322&quot;: case &quot;325&quot;: case &quot;326&quot;: case &quot;329&quot;: case &quot;332&quot;: case &quot;347&quot;: case &quot;356&quot;: case &quot;357&quot;: case &quot;360&quot;: case &quot;361&quot;: case &quot;362&quot;: case &quot;363&quot;: case &quot;364&quot;: case &quot;365&quot;: case &quot;372&quot;: case &quot;373&quot;: case &quot;377&quot;: case &quot;383&quot;: case &quot;385&quot;: case &quot;388&quot;: case &quot;390&quot;: case &quot;391&quot;: case &quot;395&quot;: case &quot;405&quot;: case &quot;406&quot;: case &quot;420&quot;: case &quot;421&quot;: case &quot;425&quot;: case &quot;426&quot;: case &quot;428&quot;: case &quot;429&quot;: case &quot;434&quot;: case &quot;440&quot;: case &quot;442&quot;: case &quot;443&quot;: case &quot;452&quot;: case &quot;453&quot;: case &quot;471&quot;: case &quot;476&quot;: case &quot;484&quot;: case &quot;487&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#addd8e&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.0, &quot;weight&quot;: 0};
#                 case &quot;2&quot;: case &quot;13&quot;: case &quot;20&quot;: case &quot;27&quot;: case &quot;227&quot;: case &quot;318&quot;: case &quot;410&quot;: case &quot;412&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#005a32&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.0, &quot;weight&quot;: 0};
#                 case &quot;3&quot;: case &quot;23&quot;: case &quot;26&quot;: case &quot;31&quot;: case &quot;40&quot;: case &quot;42&quot;: case &quot;45&quot;: case &quot;47&quot;: case &quot;48&quot;: case &quot;51&quot;:

# %%
# Out:
# (127.5, 0.0, 127.5)

# %%
election_result.results.head()
# Out:
#        id election_date county_code                contest  \
# 0  910737    2022-05-24         060  DEM - US HOUSE DIST 7
# 1  910738    2022-05-24         060  DEM - US HOUSE DIST 7
# 2  910739    2022-05-24         060  DEM - US HOUSE DIST 7
# 3  910740    2022-05-24         060  DEM - US HOUSE DIST 7
# 4  910741    2022-05-24         060  DEM - US HOUSE DIST 7
#
#                   choice party  is_question precinct_name  votes
# 0  CAROLYN BOURDEAUX (I)   DEM            0          AP14      8
# 1  CAROLYN BOURDEAUX (I)   DEM            0         AP14A     47
# 2  CAROLYN BOURDEAUX (I)   DEM            0          JC01     75
# 3  CAROLYN BOURDEAUX (I)   DEM            0         JC01A     29
# 4  CAROLYN BOURDEAUX (I)   DEM            0          JC02     64

# %%
af = election_result.results[['county_code', 'precinct_name', 'party', 'votes']].\
    groupby(['county_code', 'precinct_name', 'party']).\
    sum().reset_index()

af = af.pivot(index=['county_code', 'precinct_name'], columns='party', values='votes')
af.columns.name = None
af = af.reset_index()
af = af.assign(affinity=(af.REP / (af.REP + af.DEM)).apply(lambda x: (max(.4, min(.6, x)) - 0.4) / 0.2),
               pop_scale=(af.REP + af.DEM) / (af.REP + af.DEM).max())

vtd_maps = election_result.vtd_maps

# %%
af_marker = af.merge(vtd_maps[['county_code', 'precinct_name', 'center']], on=['county_code', 'precinct_name'],
                     how='inner')

# %%
import plotly.express as px
from plotly.colors import n_colors, find_intermediate_color

for i in af_marker.index:
    center = af_marker.loc[i].center
    x = center.x
    y = center.y
    r = af_marker.loc[i].pop_scale * 10
    c = find_intermediate_color((255, 0, 0), (0, 0, 255), af_marker.loc[i].affinity)
    pn = af_marker.loc[i].precinct_name
    folium.CircleMarker(
        location=[y, x],
        radius=r,
        popup=pn,
        color=c,
        fill=True,
        fill_color=c
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_41b5a0cfdf996b21c4e5f18a48ede317 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_41b5a0cfdf996b21c4e5f18a48ede317&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_41b5a0cfdf996b21c4e5f18a48ede317 = L.map(
#                 &quot;map_41b5a0cfdf996b21c4e5f18a48ede317&quot;,
#                 {
#                     center: [33.92266807940528, -84.05953456687884],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f02e0a8e14f05597596057c11b648e01 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_41b5a0cfdf996b21c4e5f18a48ede317);
#
#
#             map_41b5a0cfdf996b21c4e5f18a48ede317.fitBounds(
#                 [[33.75280798999031, -84.29404799999999], [34.09067899016351, -83.799104]],
#                 {}
#             );
#
#
#             var choropleth_fd2483d6b57e9670b40b48ce51dd6d86 = L.featureGroup(
#                 {}
#             ).addTo(map_41b5a0cfdf996b21c4e5f18a48ede317);
#
#
#         function geo_json_1371eca7e6ebb6ba2621e98f680ad4bb_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;6&quot;: case &quot;7&quot;: case &quot;10&quot;: case &quot;16&quot;: case &quot;18&quot;: case &quot;28&quot;: case &quot;33&quot;: case &quot;35&quot;: case &quot;39&quot;: case &quot;46&quot;: case &quot;53&quot;: case &quot;56&quot;: case &quot;65&quot;: case &quot;69&quot;: case &quot;75&quot;: case &quot;77&quot;: case &quot;90&quot;: case &quot;112&quot;: case &quot;151&quot;: case &quot;178&quot;: case &quot;207&quot;: case &quot;225&quot;: case &quot;254&quot;: case &quot;272&quot;: case &quot;371&quot;: case &quot;386&quot;: case &quot;393&quot;: case &quot;398&quot;: case &quot;473&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#41ab5d&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.0, &quot;weight&quot;: 0};
#                 case &quot;1&quot;: case &quot;5&quot;: case &quot;8&quot;: case &quot;9&quot;: case &quot;15&quot;: case &quot;24&quot;: case &quot;32&quot;: case &quot;36&quot;: case &quot;37&quot;: case &quot;57&quot;: case &quot;72&quot;: case &quot;85&quot;: case &quot;86&quot;: case &quot;88&quot;: case &quot;98&quot;: case &quot;115&quot;: case &quot;117&quot;: case &quot;121&quot;: case &quot;122&quot;: case &quot;132&quot;: case &quot;157&quot;: case &quot;166&quot;: case &quot;170&quot;: case &quot;182&quot;: case &quot;183&quot;: case &quot;191&quot;: case &quot;196&quot;: case &quot;203&quot;: case &quot;217&quot;: case &quot;220&quot;: case &quot;223&quot;: case &quot;234&quot;: case &quot;237&quot;: case &quot;251&quot;: case &quot;252&quot;: case &quot;255&quot;: case &quot;265&quot;: case &quot;267&quot;: case &quot;268&quot;: case &quot;270&quot;: case &quot;271&quot;: case &quot;274&quot;: case &quot;286&quot;: case &quot;287&quot;: case &quot;289&quot;: case &quot;292&quot;: case &quot;304&quot;: case &quot;305&quot;: case &quot;316&quot;: case &quot;322&quot;: case &quot;325&quot;: case &quot;326&quot;: case &quot;329&quot;: case &quot;332&quot;: case &quot;347&quot;: case &quot;356&quot;: case &quot;357&quot;: case &quot;360&quot;: case &quot;361&quot;: case &quot;362&quot;: case &quot;363&quot;: case &quot;364&quot;: case &quot;365&quot;: case &quot;372&quot;: case &quot;373&quot;: case &quot;377&quot;: case &quot;383&quot;: case &quot;385&quot;: case &quot;388&quot;: case &quot;390&quot;: case &quot;391&quot;: case &quot;395&quot;: case &quot;405&quot;: case &quot;406&quot;: case &quot;420&quot;: case &quot;421&quot;: case &quot;425&quot;: case &quot;426&quot;: case &quot;428&quot;: case &quot;429&quot;: case &quot;434&quot;: case &quot;440&quot;: case &quot;442&quot;: case &quot;443&quot;: case &quot;452&quot;: case &quot;453&quot;: case &quot;471&quot;: case &quot;476&quot;: case &quot;484&quot;: case &quot;487&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#addd8e&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.0, &quot;weight&quot;: 0};
#                 case &quot;2&quot;: case &quot;13&quot;: case &quot;20&quot;: case &quot;27&quot;: case &quot;227&quot;: case &quot;318&quot;: case &quot;410&quot;: case &quot;412&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#005a32&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.0, &quot;weight&quot;: 0};
#                 case &quot;3&quot;: case &quot;23&quot;: case &quot;26&quot;: case &quot;31&quot;: case &quot;40&quot;: case &quot;42&quot;: case &quot;45&quot;: case &quot;47&quot;: case &quot;48&quot;: case &quot;51&quot;:

# %%
vtd_style_function = lambda x: {
    'color': 'black',
    'weight': 1,
    'min_zoom' = 12,
                 'fillOpacity': 0.0
}

folium.GeoJson(
    vtd_maps[['geometry']],
    name='Precincts Boundaries',
    style_function=vtd_style_function,
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4ef4e858e3901e9aa670908529c49adf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4ef4e858e3901e9aa670908529c49adf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_4ef4e858e3901e9aa670908529c49adf = L.map(
#                 &quot;map_4ef4e858e3901e9aa670908529c49adf&quot;,
#                 {
#                     center: [33.92266807940528, -84.05953456687884],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_83b5518abd3bae22f709744adad032c4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4ef4e858e3901e9aa670908529c49adf);
#
#
#             map_4ef4e858e3901e9aa670908529c49adf.fitBounds(
#                 [[33.75280798999031, -84.29404799999999], [34.09067899016351, -83.799104]],
#                 {}
#             );
#
#
#             var choropleth_562e369ac09efebd5187e36c287109ab = L.featureGroup(
#                 {}
#             ).addTo(map_4ef4e858e3901e9aa670908529c49adf);
#
#
#         function geo_json_3ed9e0fad41b54fda7e7a25430c07dd8_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;6&quot;: case &quot;7&quot;: case &quot;10&quot;: case &quot;16&quot;: case &quot;18&quot;: case &quot;28&quot;: case &quot;39&quot;: case &quot;46&quot;: case &quot;53&quot;: case &quot;56&quot;: case &quot;65&quot;: case &quot;69&quot;: case &quot;71&quot;: case &quot;77&quot;: case &quot;90&quot;: case &quot;112&quot;: case &quot;151&quot;: case &quot;169&quot;: case &quot;178&quot;: case &quot;225&quot;: case &quot;254&quot;: case &quot;272&quot;: case &quot;371&quot;: case &quot;386&quot;: case &quot;393&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#41ab5d&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.0, &quot;weight&quot;: 0};
#                 case &quot;1&quot;: case &quot;5&quot;: case &quot;8&quot;: case &quot;9&quot;: case &quot;15&quot;: case &quot;24&quot;: case &quot;32&quot;: case &quot;36&quot;: case &quot;37&quot;: case &quot;47&quot;: case &quot;72&quot;: case &quot;85&quot;: case &quot;86&quot;: case &quot;88&quot;: case &quot;98&quot;: case &quot;115&quot;: case &quot;117&quot;: case &quot;121&quot;: case &quot;122&quot;: case &quot;132&quot;: case &quot;157&quot;: case &quot;166&quot;: case &quot;170&quot;: case &quot;182&quot;: case &quot;183&quot;: case &quot;191&quot;: case &quot;192&quot;: case &quot;193&quot;: case &quot;203&quot;: case &quot;220&quot;: case &quot;223&quot;: case &quot;234&quot;: case &quot;237&quot;: case &quot;251&quot;: case &quot;252&quot;: case &quot;255&quot;: case &quot;265&quot;: case &quot;267&quot;: case &quot;268&quot;: case &quot;270&quot;: case &quot;271&quot;: case &quot;274&quot;: case &quot;286&quot;: case &quot;287&quot;: case &quot;292&quot;: case &quot;304&quot;: case &quot;305&quot;: case &quot;310&quot;: case &quot;316&quot;: case &quot;322&quot;: case &quot;325&quot;: case &quot;326&quot;: case &quot;329&quot;: case &quot;332&quot;: case &quot;347&quot;: case &quot;356&quot;: case &quot;357&quot;: case &quot;360&quot;: case &quot;361&quot;: case &quot;362&quot;: case &quot;363&quot;: case &quot;364&quot;: case &quot;365&quot;: case &quot;372&quot;: case &quot;373&quot;: case &quot;377&quot;: case &quot;383&quot;: case &quot;385&quot;: case &quot;388&quot;: case &quot;390&quot;: case &quot;395&quot;: case &quot;405&quot;: case &quot;406&quot;: case &quot;420&quot;: case &quot;425&quot;: case &quot;426&quot;: case &quot;429&quot;: case &quot;434&quot;: case &quot;440&quot;: case &quot;443&quot;: case &quot;451&quot;: case &quot;452&quot;: case &quot;453&quot;: case &quot;469&quot;: case &quot;471&quot;: case &quot;476&quot;: case &quot;484&quot;: case &quot;487&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#addd8e&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.0, &quot;weight&quot;: 0};
#                 case &quot;2&quot;: case &quot;13&quot;: case &quot;20&quot;: case &quot;27&quot;: case &quot;29&quot;: case &quot;34&quot;: case &quot;38&quot;: case &quot;43&quot;: case &quot;55&quot;: case &quot;60&quot;: case &quot;120&quot;: case &quot;227&quot;: case &quot;318&quot;: case &quot;410&quot;: case &quot;475&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#005a32&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.0, &quot;weight&quot;: 0};
#                 case &quot;3&quot;: case &quot;23&quot;: case &quot;26&quot;: case &quot;31&quot;: case &quot;33&quot;: case &quot;35&quot;: case &quot;40&quot;: case &quot;42&quot;: case &quot;45&quot;: cas
